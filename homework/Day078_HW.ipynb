# %% [markdown]
# ## Work
# 1. 請嘗試將 preproc_x 替換成以每筆資料的 min/max 進行標準化至 -1 ~ 1 間，再進行訓練
# 2. 請嘗試將 mlp 疊更深 (e.g 5~10 層)，進行訓練後觀察 learning curve 的走勢
# 3. (optional) 請改用 GPU 進行訓練 (如果你有 GPU 的話)，比較使用 CPU 與 GPU 的訓練速度

# %%
## 
"""
Your code here (optional)
確認硬體資源
"""
# !nvidia-smi
# Out:
# Mon Jun 29 11:29:00 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 410.93       Driver Version: 410.93       CUDA Version: 10.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 108...  Off  | 00000000:0D:00.0 Off |                  N/A |
# | 23%   24C    P8     7W / 250W |      0MiB / 11178MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
import keras

# 請嘗試設定 GPU：os.environ
os.environ["CUDA_VISIBLE_DEVICES"] = '0'
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
"""
Your code here
"""
"""
# standardize x to -1~1
def preproc_x(x, flatten=True):
    x = (x-x.min())/(x.max()-x.min()) * 2 - 1
    if flatten:
        x = x.reshape((len(x), -1))
    return x
"""
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
"""Code Here
建立你的神經網路
"""
def build_mlp(input_shape, output_units=10, num_neurons=[512, 512, 256, 256, 256, 128, 128, 128, 64, 64]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(input_layer)
        else:
            x = keras.layers.Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 512)               262656
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer4 (Dense)        (None, 256)               65792
# _________________________________________________________________
# hidden_layer5 (Dense)        (None, 256)               65792
# _________________________________________________________________
# hidden_layer6 (Dense)        (None, 128)               32896
# _________________________________________________________________
# hidden_layer7 (Dense)        (None, 128)               16512
# _________________________________________________________________
# hidden_layer8 (Dense)        (None, 128)               16512
# _________________________________________________________________
# hidden_layer9 (Dense)        (None, 64)                8256
# _________________________________________________________________
# hidden_layer10 (Dense)       (None, 64)                4160
# _________________________________________________________________
# output (Dense)               (None, 10)                650
# =================================================================
# Total params: 2,177,930
# Trainable params: 2,177,930
# Non-trainable params: 0
# _________________________________________________________________

# %%
## 超參數設定
LEARNING_RATE = 0.001
EPOCHS = 100
BATCH_SIZE = 256

# %%
optimizer = keras.optimizers.Adam(lr=LEARNING_RATE)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

# %%
model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 4s 71us/step - loss: 2.0180 - accuracy: 0.2344 - val_loss: 1.8848 - val_accuracy: 0.3077
# Epoch 2/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.8164 - accuracy: 0.3360 - val_loss: 1.7342 - val_accuracy: 0.3672
# Epoch 3/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.7180 - accuracy: 0.3768 - val_loss: 1.6927 - val_accuracy: 0.3784
# Epoch 4/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.6393 - accuracy: 0.4080 - val_loss: 1.5911 - val_accuracy: 0.4349
# Epoch 5/100
# 50000/50000 [==============================] - 2s 41us/step - loss: 1.5890 - accuracy: 0.4301 - val_loss: 1.5688 - val_accuracy: 0.4321
# Epoch 6/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.5378 - accuracy: 0.4478 - val_loss: 1.5368 - val_accuracy: 0.4522
# Epoch 7/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.5097 - accuracy: 0.4579 - val_loss: 1.5492 - val_accuracy: 0.4538
# Epoch 8/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.4686 - accuracy: 0.4722 - val_loss: 1.5548 - val_accuracy: 0.4471
# Epoch 9/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.4343 - accuracy: 0.4852 - val_loss: 1.4982 - val_accuracy: 0.4711
# Epoch 10/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.4014 - accuracy: 0.4953 - val_loss: 1.4461 - val_accuracy: 0.4921
# Epoch 11/100
# 50000/50000 [==============================] - 2s 39us/step - loss: 1.3726 - accuracy: 0.5078 - val_loss: 1.4775 - val_accuracy: 0.4737
# Epoch 12/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.3520 - accuracy: 0.5164 - val_loss: 1.4278 - val_accuracy: 0.4927
# Epoch 13/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.3290 - accuracy: 0.5216 - val_loss: 1.4176 - val_accuracy: 0.4975
# Epoch 14/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.2924 - accuracy: 0.5351 - val_loss: 1.4088 - val_accuracy: 0.5071
# Epoch 15/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.2679 - accuracy: 0.5446 - val_loss: 1.4278 - val_accuracy: 0.4969
# Epoch 16/100
# 50000/50000 [==============================] - 2s 39us/step - loss: 1.2542 - accuracy: 0.5507 - val_loss: 1.4349 - val_accuracy: 0.4955
# Epoch 17/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.2206 - accuracy: 0.5645 - val_loss: 1.4209 - val_accuracy: 0.5037
# Epoch 18/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.1899 - accuracy: 0.5726 - val_loss: 1.3907 - val_accuracy: 0.5142
# Epoch 19/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.1618 - accuracy: 0.5826 - val_loss: 1.4397 - val_accuracy: 0.4935
# Epoch 20/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.1402 - accuracy: 0.5909 - val_loss: 1.4656 - val_accuracy: 0.4962
# Epoch 21/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.1074 - accuracy: 0.6033 - val_loss: 1.4677 - val_accuracy: 0.5043
# Epoch 22/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.0788 - accuracy: 0.6118 - val_loss: 1.4616 - val_accuracy: 0.5139
# Epoch 23/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 1.0616 - accuracy: 0.6183 - val_loss: 1.4953 - val_accuracy: 0.4922
# Epoch 24/100
# 50000/50000 [==============================] - 2s 39us/step - loss: 1.0339 - accuracy: 0.6268 - val_loss: 1.4616 - val_accuracy: 0.5101
# Epoch 25/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.9988 - accuracy: 0.6399 - val_loss: 1.4496 - val_accuracy: 0.5114
# Epoch 26/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.9666 - accuracy: 0.6495 - val_loss: 1.5057 - val_accuracy: 0.5094
# Epoch 27/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.9426 - accuracy: 0.6624 - val_loss: 1.5122 - val_accuracy: 0.5081
# Epoch 28/100
# 50000/50000 [==============================] - 2s 41us/step - loss: 0.9187 - accuracy: 0.6699 - val_loss: 1.5412 - val_accuracy: 0.5028
# Epoch 29/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.8903 - accuracy: 0.6805 - val_loss: 1.6022 - val_accuracy: 0.5103
# Epoch 30/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.8487 - accuracy: 0.6945 - val_loss: 1.6305 - val_accuracy: 0.5015
# Epoch 31/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.8346 - accuracy: 0.6969 - val_loss: 1.7484 - val_accuracy: 0.4986
# Epoch 32/100
# 50000/50000 [==============================] - 2s 39us/step - loss: 0.8037 - accuracy: 0.7110 - val_loss: 1.6355 - val_accuracy: 0.5084
# Epoch 33/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.7915 - accuracy: 0.7139 - val_loss: 1.6519 - val_accuracy: 0.5035
# Epoch 34/100
# 50000/50000 [==============================] - 2s 39us/step - loss: 0.7602 - accuracy: 0.7251 - val_loss: 1.7907 - val_accuracy: 0.4973
# Epoch 35/100
# 50000/50000 [==============================] - 2s 41us/step - loss: 0.7428 - accuracy: 0.7326 - val_loss: 1.7665 - val_accuracy: 0.4991
# Epoch 36/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.7183 - accuracy: 0.7402 - val_loss: 1.8316 - val_accuracy: 0.5035
# Epoch 37/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.6849 - accuracy: 0.7530 - val_loss: 1.8186 - val_accuracy: 0.4938
# Epoch 38/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.6798 - accuracy: 0.7557 - val_loss: 1.8595 - val_accuracy: 0.5007
# Epoch 39/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.6448 - accuracy: 0.7672 - val_loss: 1.9376 - val_accuracy: 0.5018
# Epoch 40/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.6326 - accuracy: 0.7731 - val_loss: 1.9740 - val_accuracy: 0.5008
# Epoch 41/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.5999 - accuracy: 0.7836 - val_loss: 1.9904 - val_accuracy: 0.4981
# Epoch 42/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.5782 - accuracy: 0.7934 - val_loss: 2.1127 - val_accuracy: 0.4945
# Epoch 43/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.5535 - accuracy: 0.7997 - val_loss: 2.2440 - val_accuracy: 0.4743
# Epoch 44/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.5474 - accuracy: 0.8030 - val_loss: 2.2094 - val_accuracy: 0.4974
# Epoch 45/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.5367 - accuracy: 0.8075 - val_loss: 2.1750 - val_accuracy: 0.4868
# Epoch 46/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.5019 - accuracy: 0.8210 - val_loss: 2.2598 - val_accuracy: 0.4938
# Epoch 47/100
# 50000/50000 [==============================] - 2s 41us/step - loss: 0.4924 - accuracy: 0.8223 - val_loss: 2.3394 - val_accuracy: 0.4906
# Epoch 48/100
# 50000/50000 [==============================] - 2s 41us/step - loss: 0.4824 - accuracy: 0.8277 - val_loss: 2.4130 - val_accuracy: 0.4867
# Epoch 49/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.4655 - accuracy: 0.8332 - val_loss: 2.3411 - val_accuracy: 0.4884
# Epoch 50/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.4427 - accuracy: 0.8444 - val_loss: 2.1186 - val_accuracy: 0.4877
# Epoch 51/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.4449 - accuracy: 0.8415 - val_loss: 2.3360 - val_accuracy: 0.4885
# Epoch 52/100
# 50000/50000 [==============================] - 2s 41us/step - loss: 0.4269 - accuracy: 0.8472 - val_loss: 2.4588 - val_accuracy: 0.4891
# Epoch 53/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.4038 - accuracy: 0.8553 - val_loss: 2.4822 - val_accuracy: 0.4859
# Epoch 54/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.4015 - accuracy: 0.8580 - val_loss: 2.5884 - val_accuracy: 0.4952
# Epoch 55/100
# 50000/50000 [==============================] - 2s 39us/step - loss: 0.3799 - accuracy: 0.8647 - val_loss: 2.5448 - val_accuracy: 0.4897
# Epoch 56/100
# 50000/50000 [==============================] - 2s 41us/step - loss: 0.3852 - accuracy: 0.8620 - val_loss: 2.4500 - val_accuracy: 0.4885
# Epoch 57/100
# 50000/50000 [==============================] - 2s 41us/step - loss: 0.3553 - accuracy: 0.8749 - val_loss: 2.6992 - val_accuracy: 0.4911
# Epoch 58/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.3601 - accuracy: 0.8732 - val_loss: 2.7598 - val_accuracy: 0.4953
# Epoch 59/100
# 50000/50000 [==============================] - 2s 41us/step - loss: 0.3375 - accuracy: 0.8793 - val_loss: 2.8564 - val_accuracy: 0.4883
# Epoch 60/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.3356 - accuracy: 0.8814 - val_loss: 2.7220 - val_accuracy: 0.4871
# Epoch 61/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.3272 - accuracy: 0.8838 - val_loss: 2.7817 - val_accuracy: 0.4898
# Epoch 62/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.3196 - accuracy: 0.8894 - val_loss: 2.7579 - val_accuracy: 0.4954
# Epoch 63/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.3139 - accuracy: 0.8887 - val_loss: 2.6648 - val_accuracy: 0.4896
# Epoch 64/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.3096 - accuracy: 0.8925 - val_loss: 2.6613 - val_accuracy: 0.4945
# Epoch 65/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.2901 - accuracy: 0.8979 - val_loss: 2.8173 - val_accuracy: 0.4874
# Epoch 66/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.2833 - accuracy: 0.9004 - val_loss: 2.9472 - val_accuracy: 0.4918
# Epoch 67/100
# 50000/50000 [==============================] - 2s 41us/step - loss: 0.3063 - accuracy: 0.8939 - val_loss: 2.9429 - val_accuracy: 0.4778
# Epoch 68/100
# 50000/50000 [==============================] - 2s 41us/step - loss: 0.2930 - accuracy: 0.8983 - val_loss: 2.8708 - val_accuracy: 0.4946
# Epoch 69/100
# 50000/50000 [==============================] - 2s 41us/step - loss: 0.2689 - accuracy: 0.9069 - val_loss: 3.0434 - val_accuracy: 0.4921
# Epoch 70/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.2619 - accuracy: 0.9103 - val_loss: 3.1504 - val_accuracy: 0.4853
# Epoch 71/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.2694 - accuracy: 0.9065 - val_loss: 3.0169 - val_accuracy: 0.4866
# Epoch 72/100
# 50000/50000 [==============================] - 2s 41us/step - loss: 0.2528 - accuracy: 0.9117 - val_loss: 3.0821 - val_accuracy: 0.4813
# Epoch 73/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.2653 - accuracy: 0.9091 - val_loss: 3.2352 - val_accuracy: 0.4781
# Epoch 74/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.2417 - accuracy: 0.9171 - val_loss: 2.9352 - val_accuracy: 0.4857
# Epoch 75/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.2334 - accuracy: 0.9194 - val_loss: 2.9712 - val_accuracy: 0.4929
# Epoch 76/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.2346 - accuracy: 0.9185 - val_loss: 3.1484 - val_accuracy: 0.4859
# Epoch 77/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.2437 - accuracy: 0.9163 - val_loss: 2.9644 - val_accuracy: 0.4815
# Epoch 78/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.2204 - accuracy: 0.9226 - val_loss: 3.0910 - val_accuracy: 0.4936
# Epoch 79/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.2441 - accuracy: 0.9162 - val_loss: 3.0009 - val_accuracy: 0.4882
# Epoch 80/100
# 50000/50000 [==============================] - 2s 41us/step - loss: 0.2160 - accuracy: 0.9261 - val_loss: 2.8781 - val_accuracy: 0.4859
# Epoch 81/100
# 50000/50000 [==============================] - 2s 41us/step - loss: 0.2195 - accuracy: 0.9252 - val_loss: 3.1215 - val_accuracy: 0.4785
# Epoch 82/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.2145 - accuracy: 0.9271 - val_loss: 2.8761 - val_accuracy: 0.4813
# Epoch 83/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.2267 - accuracy: 0.9218 - val_loss: 3.4000 - val_accuracy: 0.4849
# Epoch 84/100
# 50000/50000 [==============================] - 2s 41us/step - loss: 0.2066 - accuracy: 0.9284 - val_loss: 3.3070 - val_accuracy: 0.4828
# Epoch 85/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.2162 - accuracy: 0.9271 - val_loss: 2.9742 - val_accuracy: 0.4900
# Epoch 86/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.2014 - accuracy: 0.9310 - val_loss: 3.3034 - val_accuracy: 0.4904
# Epoch 87/100
# 50000/50000 [==============================] - 2s 41us/step - loss: 0.2015 - accuracy: 0.9304 - val_loss: 2.9903 - val_accuracy: 0.4869
# Epoch 88/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.1854 - accuracy: 0.9352 - val_loss: 3.3366 - val_accuracy: 0.4897
# Epoch 89/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.1945 - accuracy: 0.9338 - val_loss: 3.1012 - val_accuracy: 0.4763
# Epoch 90/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.1846 - accuracy: 0.9370 - val_loss: 3.4614 - val_accuracy: 0.4883
# Epoch 91/100
# 50000/50000 [==============================] - 2s 41us/step - loss: 0.1902 - accuracy: 0.9351 - val_loss: 3.2143 - val_accuracy: 0.4832
# Epoch 92/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.2051 - accuracy: 0.9306 - val_loss: 3.0150 - val_accuracy: 0.4853
# Epoch 93/100
# 50000/50000 [==============================] - 2s 41us/step - loss: 0.1936 - accuracy: 0.9333 - val_loss: 3.2270 - val_accuracy: 0.4854
# Epoch 94/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.1745 - accuracy: 0.9404 - val_loss: 3.2886 - val_accuracy: 0.4873
# Epoch 95/100
# 50000/50000 [==============================] - 2s 41us/step - loss: 0.1688 - accuracy: 0.9421 - val_loss: 3.3941 - val_accuracy: 0.4833
# Epoch 96/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.1776 - accuracy: 0.9408 - val_loss: 3.3552 - val_accuracy: 0.4795
# Epoch 97/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.1727 - accuracy: 0.9406 - val_loss: 3.6374 - val_accuracy: 0.4839
# Epoch 98/100
# 50000/50000 [==============================] - 2s 41us/step - loss: 0.1626 - accuracy: 0.9455 - val_loss: 3.3672 - val_accuracy: 0.4840
# Epoch 99/100
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.1759 - accuracy: 0.9411 - val_loss: 3.3841 - val_accuracy: 0.4829
# Epoch 100/100
# 50000/50000 [==============================] - 2s 41us/step - loss: 0.1747 - accuracy: 0.9410 - val_loss: 3.3384 - val_accuracy: 0.4863

# %% [markdown]
# ### preproc_x 替換成以每筆資料的 min/max 進行標準化至 -1 ~ 1

# %%
import matplotlib.pyplot as plt


train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]

train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

# %% [markdown]
# ### 將 mlp 疊到10層，進行訓練後觀察 learning curve 的走勢

# %%
import matplotlib.pyplot as plt


train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]

train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

# %% [markdown]
# ### 改用 GPU 進行訓練 (如果你有 GPU 的話)，比較使用 CPU 與 GPU 的訓練速度

# %%
import matplotlib.pyplot as plt


train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]

train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

# %% [markdown]
# ### without GPU
# #### 140~150 us for each step
# #### 7-8 s for each epochs
#
# ### with GPU
# #### 40~70 us for each step
# #### 2-4 s for each epochs
