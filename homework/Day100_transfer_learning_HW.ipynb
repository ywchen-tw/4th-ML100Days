# %% [markdown]
# ## 作業
# 礙於不是所有同學都有 GPU ，這邊的範例使用的是簡化版本的 ResNet，確保所有同學都能夠順利訓練!
#
#
# 最後一天的作業請閱讀這篇非常詳盡的[文章](https://blog.gtwang.org/programming/keras-resnet-50-pre-trained-model-build-dogs-cats-image-classification-system/)，基本上已經涵蓋了所有訓練　CNN 常用的技巧，請使用所有學過的訓練技巧，盡可能地提高 Cifar-10 的 test data 準確率，截圖你最佳的結果並上傳來完成最後一次的作業吧!
#
# 另外這些技巧在 Kaggle 上也會被許多人使用，更有人會開發一些新的技巧，例如使把預訓練在 ImageNet 上的模型當成 feature extractor 後，再拿擷取出的特徵重新訓練新的模型，這些技巧再進階的課程我們會在提到，有興趣的同學也可以[參考](https://www.kaggle.com/insaff/img-feature-extraction-with-pretrained-resnet)

# %%
from keras.datasets import cifar10
from keras.applications.resnet50 import ResNet50
from resnet_builder import resnet
from keras.utils import to_categorical
from keras.preprocessing.image import ImageDataGenerator
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import RMSprop, Adam
from keras.applications import NASNetLarge, MobileNetV2, ResNet101
from keras.models import Model
import os
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from keras.preprocessing import image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

os.environ["CUDA_VISIBLE_DEVICES"] = "0, 1"
# Out:
# Using TensorFlow backend.

# %%
# 讀取資料集並作前處理
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

x_train = x_train / 255.
x_test = x_test / 255.
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
# 影像大小
IMAGE_SIZE = (32, 32)

# 影像類別數
NUM_CLASSES = 10

# 若 GPU 記憶體不足，可調降 batch size 或凍結更多層網路
BATCH_SIZE = 64

# 凍結網路層數
FREEZE_LAYERS = 0

# Epoch 數
NUM_EPOCHS = 50

# 模型輸出儲存的檔案
WEIGHTS_FINAL = 'model-NASNetLarge-final_2.h5'

# %%
train_datagen = ImageDataGenerator(width_shift_range=0.1,
                                   height_shift_range=0.1,
                                   shear_range=0.1,
                                   zoom_range=0.1,
                                   channel_shift_range=2,
                                   horizontal_flip=False,
                                   #samplewise_center=True,
                                   #samplewise_std_normalization=True,
                                   fill_mode='nearest')
"""
train_batches = train_datagen.flow_from_directory(DATASET_PATH + '/train',
                                                  target_size=IMAGE_SIZE,
                                                  interpolation='lanczos',
                                                  class_mode='categorical',
                                                  shuffle=True,
                                                  batch_size=BATCH_SIZE)
"""
train_batches = train_datagen.flow(x_train, y_train, batch_size=BATCH_SIZE)

# %%
# 以訓練好的 ResNet50 為基礎來建立模型，
# 捨棄 ResNet50 頂層的 fully connected layers
net = ResNet101(include_top=False, weights='imagenet', input_tensor=None,
               input_shape=(IMAGE_SIZE[0],IMAGE_SIZE[1],3))
x = net.output
x = Flatten()(x)

# 增加 DropOut layer
x = Dropout(0.5)(x)

# 增加 Dense layer，以 softmax 產生個類別的機率值
output_layer = Dense(NUM_CLASSES, activation='softmax', name='softmax')(x)

# 設定凍結與要進行訓練的網路層
model = Model(inputs=net.input, outputs=output_layer)
for layer in model.layers[:FREEZE_LAYERS]:
    layer.trainable = False
for layer in model.layers[FREEZE_LAYERS:]:
    layer.trainable = True

# load weights
model.load_weights('./HW_100_ResNet101.hdf5')
    
# 使用 Adam optimizer，以較低的 learning rate 進行 fine-tuning
model.compile(#optimizer=RMSprop(lr=1e-2), #Adam(lr=1e-2),
              optimizer=Adam(lr=1e-2),  
              loss='categorical_crossentropy', metrics=['accuracy'])

print(model.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 38, 38, 3)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 16, 16, 64)   9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 16, 16, 64)   256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 16, 16, 64)   0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 18, 18, 64)   0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 8, 8, 64)     0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 8, 8, 64)     4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 8, 8, 64)     0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 8, 8, 64)     0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 8, 8, 256)    16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 8, 8, 256)    16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 8, 8, 256)    1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 8, 8, 256)    1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 8, 8, 256)    0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 8, 8, 256)    0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 8, 8, 64)     16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 8, 8, 64)     0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 8, 8, 64)     0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 8, 8, 256)    16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 8, 8, 256)    1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 8, 8, 256)    0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 8, 8, 256)    0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 8, 8, 64)     16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 8, 8, 64)     0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 8, 8, 64)     36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 8, 8, 64)     256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 8, 8, 64)     0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 8, 8, 256)    16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 8, 8, 256)    1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 8, 8, 256)    0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 8, 8, 256)    0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 4, 4, 128)    32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 4, 4, 128)    0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 4, 4, 128)    0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 4, 4, 512)    131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 4, 4, 512)    66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 4, 4, 512)    2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 4, 4, 512)    2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 4, 4, 512)    0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 4, 4, 512)    0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 4, 4, 128)    65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 4, 4, 128)    0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 4, 4, 128)    0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 4, 4, 512)    66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 4, 4, 512)    2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 4, 4, 512)    0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 4, 4, 512)    0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 4, 4, 128)    65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 4, 4, 128)    0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 4, 4, 128)    0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 4, 4, 512)    66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 4, 4, 512)    2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 4, 4, 512)    0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 4, 4, 512)    0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 4, 4, 128)    65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 4, 4, 128)    0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 4, 4, 128)    147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 4, 4, 128)    512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 4, 4, 128)    0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 4, 4, 512)    66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 4, 4, 512)    2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 4, 4, 512)    0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 4, 4, 512)    0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 2, 2, 256)    131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 2, 2, 256)    0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 2, 2, 256)    0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 2, 2, 1024)   525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 2, 2, 1024)   0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 2, 2, 1024)   0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 2, 2, 256)    0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 2, 2, 256)    0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 2, 2, 1024)   0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 2, 2, 1024)   0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 2, 2, 256)    0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 2, 2, 256)    0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 2, 2, 1024)   0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 2, 2, 1024)   0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 2, 2, 256)    0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 2, 2, 256)    0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 2, 2, 1024)   0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 2, 2, 1024)   0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 2, 2, 256)    0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 2, 2, 256)    0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 2, 2, 1024)   0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 2, 2, 1024)   0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 2, 2, 256)    0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 2, 2, 256)    0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 2, 2, 1024)   0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 2, 2, 1024)   0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (Activation (None, 2, 2, 256)    0           conv4_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_relu (Activation (None, 2, 2, 256)    0           conv4_block7_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block7_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block7_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_add (Add)          (None, 2, 2, 1024)   0           conv4_block6_out[0][0]
#                                                                  conv4_block7_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_out (Activation)   (None, 2, 2, 1024)   0           conv4_block7_add[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block7_out[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_relu (Activation (None, 2, 2, 256)    0           conv4_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_relu (Activation (None, 2, 2, 256)    0           conv4_block8_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block8_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block8_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_add (Add)          (None, 2, 2, 1024)   0           conv4_block7_out[0][0]
#                                                                  conv4_block8_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_out (Activation)   (None, 2, 2, 1024)   0           conv4_block8_add[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_conv (Conv2D)    (None, 2, 2, 256)    262400      conv4_block8_out[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_relu (Activation (None, 2, 2, 256)    0           conv4_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_conv (Conv2D)    (None, 2, 2, 256)    590080      conv4_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_bn (BatchNormali (None, 2, 2, 256)    1024        conv4_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_relu (Activation (None, 2, 2, 256)    0           conv4_block9_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_3_conv (Conv2D)    (None, 2, 2, 1024)   263168      conv4_block9_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_3_bn (BatchNormali (None, 2, 2, 1024)   4096        conv4_block9_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_add (Add)          (None, 2, 2, 1024)   0           conv4_block8_out[0][0]
#                                                                  conv4_block9_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_out (Activation)   (None, 2, 2, 1024)   0           conv4_block9_add[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_conv (Conv2D)   (None, 2, 2, 256)    262400      conv4_block9_out[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_bn (BatchNormal (None, 2, 2, 256)    1024        conv4_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_relu (Activatio (None, 2, 2, 256)    0           conv4_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_conv (Conv2D)   (None, 2, 2, 256)    590080      conv4_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_bn (BatchNormal (None, 2, 2, 256)    1024        conv4_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_relu (Activatio (None, 2, 2, 256)    0           conv4_block10_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_3_conv (Conv2D)   (None, 2, 2, 1024)   263168      conv4_block10_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_3_bn (BatchNormal (None, 2, 2, 1024)   4096        conv4_block10_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_add (Add)         (None, 2, 2, 1024)   0           conv4_block9_out[0][0]
#                                                                  conv4_block10_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_out (Activation)  (None, 2, 2, 1024)   0           conv4_block10_add[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_conv (Conv2D)   (None, 2, 2, 256)    262400      conv4_block10_out[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_bn (BatchNormal (None, 2, 2, 256)    1024        conv4_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_relu (Activatio (None, 2, 2, 256)    0           conv4_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_conv (Conv2D)   (None, 2, 2, 256)    590080      conv4_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_bn (BatchNormal (None, 2, 2, 256)    1024        conv4_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_relu (Activatio (None, 2, 2, 256)    0           conv4_block11_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_3_conv (Conv2D)   (None, 2, 2, 1024)   263168      conv4_block11_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_3_bn (BatchNormal (None, 2, 2, 1024)   4096        conv4_block11_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_add (Add)         (None, 2, 2, 1024)   0           conv4_block10_out[0][0]
#                                                                  conv4_block11_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_out (Activation)  (None, 2, 2, 1024)   0           conv4_block11_add[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_conv (Conv2D)   (None, 2, 2, 256)    262400      conv4_block11_out[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_bn (BatchNormal (None, 2, 2, 256)    1024        conv4_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_relu (Activatio (None, 2, 2, 256)    0           conv4_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_conv (Conv2D)   (None, 2, 2, 256)    590080      conv4_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_bn (BatchNormal (None, 2, 2, 256)    1024        conv4_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_relu (Activatio (None, 2, 2, 256)    0           conv4_block12_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_3_conv (Conv2D)   (None, 2, 2, 1024)   263168      conv4_block12_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_3_bn (BatchNormal (None, 2, 2, 1024)   4096        conv4_block12_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_add (Add)         (None, 2, 2, 1024)   0           conv4_block11_out[0][0]
#                                                                  conv4_block12_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_out (Activation)  (None, 2, 2, 1024)   0           conv4_block12_add[0][0]
# __________________________________________________________________________________________________
# conv4_block13_1_conv (Conv2D)   (None, 2, 2, 256)    262400      conv4_block12_out[0][0]
# __________________________________________________________________________________________________
# conv4_block13_1_bn (BatchNormal (None, 2, 2, 256)    1024        conv4_block13_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_1_relu (Activatio (None, 2, 2, 256)    0           conv4_block13_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_conv (Conv2D)   (None, 2, 2, 256)    590080      conv4_block13_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_bn (BatchNormal (None, 2, 2, 256)    1024        conv4_block13_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_relu (Activatio (None, 2, 2, 256)    0           conv4_block13_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block13_3_conv (Conv2D)   (None, 2, 2, 1024)   263168      conv4_block13_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block13_3_bn (BatchNormal (None, 2, 2, 1024)   4096        conv4_block13_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_add (Add)         (None, 2, 2, 1024)   0           conv4_block12_out[0][0]
#                                                                  conv4_block13_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block13_out (Activation)  (None, 2, 2, 1024)   0           conv4_block13_add[0][0]
# __________________________________________________________________________________________________
# conv4_block14_1_conv (Conv2D)   (None, 2, 2, 256)    262400      conv4_block13_out[0][0]
# __________________________________________________________________________________________________
# conv4_block14_1_bn (BatchNormal (None, 2, 2, 256)    1024        conv4_block14_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block14_1_relu (Activatio (None, 2, 2, 256)    0           conv4_block14_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block14_2_conv (Conv2D)   (None, 2, 2, 256)    590080      conv4_block14_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block14_2_bn (BatchNormal (None, 2, 2, 256)    1024        conv4_block14_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block14_2_relu (Activatio (None, 2, 2, 256)    0           conv4_block14_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block14_3_conv (Conv2D)   (None, 2, 2, 1024)   263168      conv4_block14_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block14_3_bn (BatchNormal (None, 2, 2, 1024)   4096        conv4_block14_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block14_add (Add)         (None, 2, 2, 1024)   0           conv4_block13_out[0][0]
#                                                                  conv4_block14_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block14_out (Activation)  (None, 2, 2, 1024)   0           conv4_block14_add[0][0]
# __________________________________________________________________________________________________
# conv4_block15_1_conv (Conv2D)   (None, 2, 2, 256)    262400      conv4_block14_out[0][0]
# __________________________________________________________________________________________________
# conv4_block15_1_bn (BatchNormal (None, 2, 2, 256)    1024        conv4_block15_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block15_1_relu (Activatio (None, 2, 2, 256)    0           conv4_block15_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block15_2_conv (Conv2D)   (None, 2, 2, 256)    590080      conv4_block15_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block15_2_bn (BatchNormal (None, 2, 2, 256)    1024        conv4_block15_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block15_2_relu (Activatio (None, 2, 2, 256)    0           conv4_block15_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block15_3_conv (Conv2D)   (None, 2, 2, 1024)   263168      conv4_block15_2_relu[0][0]
# __________________________________________________________________________________________________
# ...
# conv4_block19_out (Activation)  (None, 2, 2, 1024)   0           conv4_block19_add[0][0]
# __________________________________________________________________________________________________
# conv4_block20_1_conv (Conv2D)   (None, 2, 2, 256)    262400      conv4_block19_out[0][0]
# __________________________________________________________________________________________________
# conv4_block20_1_bn (BatchNormal (None, 2, 2, 256)    1024        conv4_block20_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block20_1_relu (Activatio (None, 2, 2, 256)    0           conv4_block20_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block20_2_conv (Conv2D)   (None, 2, 2, 256)    590080      conv4_block20_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block20_2_bn (BatchNormal (None, 2, 2, 256)    1024        conv4_block20_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block20_2_relu (Activatio (None, 2, 2, 256)    0           conv4_block20_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block20_3_conv (Conv2D)   (None, 2, 2, 1024)   263168      conv4_block20_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block20_3_bn (BatchNormal (None, 2, 2, 1024)   4096        conv4_block20_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block20_add (Add)         (None, 2, 2, 1024)   0           conv4_block19_out[0][0]
#                                                                  conv4_block20_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block20_out (Activation)  (None, 2, 2, 1024)   0           conv4_block20_add[0][0]
# __________________________________________________________________________________________________
# conv4_block21_1_conv (Conv2D)   (None, 2, 2, 256)    262400      conv4_block20_out[0][0]
# __________________________________________________________________________________________________
# conv4_block21_1_bn (BatchNormal (None, 2, 2, 256)    1024        conv4_block21_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block21_1_relu (Activatio (None, 2, 2, 256)    0           conv4_block21_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block21_2_conv (Conv2D)   (None, 2, 2, 256)    590080      conv4_block21_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block21_2_bn (BatchNormal (None, 2, 2, 256)    1024        conv4_block21_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block21_2_relu (Activatio (None, 2, 2, 256)    0           conv4_block21_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block21_3_conv (Conv2D)   (None, 2, 2, 1024)   263168      conv4_block21_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block21_3_bn (BatchNormal (None, 2, 2, 1024)   4096        conv4_block21_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block21_add (Add)         (None, 2, 2, 1024)   0           conv4_block20_out[0][0]
#                                                                  conv4_block21_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block21_out (Activation)  (None, 2, 2, 1024)   0           conv4_block21_add[0][0]
# __________________________________________________________________________________________________
# conv4_block22_1_conv (Conv2D)   (None, 2, 2, 256)    262400      conv4_block21_out[0][0]
# __________________________________________________________________________________________________
# conv4_block22_1_bn (BatchNormal (None, 2, 2, 256)    1024        conv4_block22_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block22_1_relu (Activatio (None, 2, 2, 256)    0           conv4_block22_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block22_2_conv (Conv2D)   (None, 2, 2, 256)    590080      conv4_block22_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block22_2_bn (BatchNormal (None, 2, 2, 256)    1024        conv4_block22_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block22_2_relu (Activatio (None, 2, 2, 256)    0           conv4_block22_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block22_3_conv (Conv2D)   (None, 2, 2, 1024)   263168      conv4_block22_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block22_3_bn (BatchNormal (None, 2, 2, 1024)   4096        conv4_block22_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block22_add (Add)         (None, 2, 2, 1024)   0           conv4_block21_out[0][0]
#                                                                  conv4_block22_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block22_out (Activation)  (None, 2, 2, 1024)   0           conv4_block22_add[0][0]
# __________________________________________________________________________________________________
# conv4_block23_1_conv (Conv2D)   (None, 2, 2, 256)    262400      conv4_block22_out[0][0]
# __________________________________________________________________________________________________
# conv4_block23_1_bn (BatchNormal (None, 2, 2, 256)    1024        conv4_block23_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block23_1_relu (Activatio (None, 2, 2, 256)    0           conv4_block23_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block23_2_conv (Conv2D)   (None, 2, 2, 256)    590080      conv4_block23_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block23_2_bn (BatchNormal (None, 2, 2, 256)    1024        conv4_block23_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block23_2_relu (Activatio (None, 2, 2, 256)    0           conv4_block23_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block23_3_conv (Conv2D)   (None, 2, 2, 1024)   263168      conv4_block23_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block23_3_bn (BatchNormal (None, 2, 2, 1024)   4096        conv4_block23_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block23_add (Add)         (None, 2, 2, 1024)   0           conv4_block22_out[0][0]
#                                                                  conv4_block23_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block23_out (Activation)  (None, 2, 2, 1024)   0           conv4_block23_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 1, 1, 512)    524800      conv4_block23_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 1, 1, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 1, 1, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 1, 1, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 1, 1, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 1, 1, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 1, 1, 2048)   2099200     conv4_block23_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 1, 1, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 1, 1, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 1, 1, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 1, 1, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 1, 1, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 1, 1, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 1, 1, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 1, 1, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 1, 1, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 1, 1, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 1, 1, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 1, 1, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 1, 1, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 1, 1, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 1, 1, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 1, 1, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 1, 1, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 1, 1, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 1, 1, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 1, 1, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 1, 1, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 1, 1, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 1, 1, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 1, 1, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 1, 1, 2048)   0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2048)         0           conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 2048)         0           flatten_1[0][0]
# __________________________________________________________________________________________________
# softmax (Dense)                 (None, 10)           20490       dropout_1[0][0]
# ==================================================================================================
# Total params: 42,678,666
# Trainable params: 42,573,322
# Non-trainable params: 105,344
# __________________________________________________________________________________________________
# None

# %%
batch_size = BATCH_SIZE # batch 的大小，如果出現 OOM error，請降低這個值
num_classes = 10 # 類別的數量，Cifar 10 共有 10 個類別
epochs = 150 # 訓練整個資料集共 30個循環

# Learning rate func
learning_rate_function = ReduceLROnPlateau(monitor='val_accuracy', 
                                            patience=3, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=1e-8)
# set check point
file_path="./HW_100_ResNet101.hdf5"
checkpoint = ModelCheckpoint(file_path, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')


# 訓練模型
"""
history = model.fit_generator(train_batches,
                                steps_per_epoch = len(train_batches) // BATCH_SIZE,
                                validation_data = (x_test, y_test),
                                epochs = NUM_EPOCHS,
                                callbacks=[learning_rate_function, checkpoint])
#"""
#"""
history = model.fit(x_train, y_train,
                    batch_size=BATCH_SIZE,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test),
                    callbacks=[learning_rate_function, checkpoint])
#"""
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/150
# 50000/50000 [==============================] - 140s 3ms/step - loss: 4.7281 - accuracy: 0.1060 - val_loss: 7.8590 - val_accuracy: 0.1061
#
# Epoch 00001: val_accuracy improved from -inf to 0.10610, saving model to ./HW_100_ResNet101.hdf5
# Epoch 2/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 3.3714 - accuracy: 0.1359 - val_loss: 4.8306 - val_accuracy: 0.1474
#
# Epoch 00002: val_accuracy improved from 0.10610 to 0.14740, saving model to ./HW_100_ResNet101.hdf5
# Epoch 3/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 2.0822 - accuracy: 0.2013 - val_loss: 2.0088 - val_accuracy: 0.2345
#
# Epoch 00003: val_accuracy improved from 0.14740 to 0.23450, saving model to ./HW_100_ResNet101.hdf5
# Epoch 4/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 1.9855 - accuracy: 0.2434 - val_loss: 1.8582 - val_accuracy: 0.2851
#
# Epoch 00004: val_accuracy improved from 0.23450 to 0.28510, saving model to ./HW_100_ResNet101.hdf5
# Epoch 5/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 1.9311 - accuracy: 0.2684 - val_loss: 4.2755 - val_accuracy: 0.2161
#
# Epoch 00005: val_accuracy did not improve from 0.28510
# Epoch 6/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 1.8428 - accuracy: 0.3067 - val_loss: 2.8937 - val_accuracy: 0.2071
#
# Epoch 00006: val_accuracy did not improve from 0.28510
# Epoch 7/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 1.7752 - accuracy: 0.3379 - val_loss: 1.9121 - val_accuracy: 0.3200
#
# Epoch 00007: val_accuracy improved from 0.28510 to 0.32000, saving model to ./HW_100_ResNet101.hdf5
# Epoch 8/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 1.7170 - accuracy: 0.3629 - val_loss: 1.6934 - val_accuracy: 0.3624
#
# Epoch 00008: val_accuracy improved from 0.32000 to 0.36240, saving model to ./HW_100_ResNet101.hdf5
# Epoch 9/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 1.6661 - accuracy: 0.3877 - val_loss: 1.7798 - val_accuracy: 0.3633
#
# Epoch 00009: val_accuracy improved from 0.36240 to 0.36330, saving model to ./HW_100_ResNet101.hdf5
# Epoch 10/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 1.6890 - accuracy: 0.3786 - val_loss: 1.5822 - val_accuracy: 0.4174
#
# Epoch 00010: val_accuracy improved from 0.36330 to 0.41740, saving model to ./HW_100_ResNet101.hdf5
# Epoch 11/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 1.5531 - accuracy: 0.4370 - val_loss: 1.8534 - val_accuracy: 0.3648
#
# Epoch 00011: val_accuracy did not improve from 0.41740
# Epoch 12/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 1.4666 - accuracy: 0.4782 - val_loss: 1.4945 - val_accuracy: 0.4752
#
# Epoch 00012: val_accuracy improved from 0.41740 to 0.47520, saving model to ./HW_100_ResNet101.hdf5
# Epoch 13/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 1.3978 - accuracy: 0.5050 - val_loss: 1.3645 - val_accuracy: 0.5137
#
# Epoch 00013: val_accuracy improved from 0.47520 to 0.51370, saving model to ./HW_100_ResNet101.hdf5
# Epoch 14/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 1.3072 - accuracy: 0.5421 - val_loss: 1.4153 - val_accuracy: 0.5126
#
# Epoch 00014: val_accuracy did not improve from 0.51370
# Epoch 15/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 1.2160 - accuracy: 0.5795 - val_loss: 3.1549 - val_accuracy: 0.3415
#
# Epoch 00015: val_accuracy did not improve from 0.51370
# Epoch 16/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 1.1374 - accuracy: 0.6110 - val_loss: 2.2011 - val_accuracy: 0.4081
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 00016: val_accuracy did not improve from 0.51370
# Epoch 17/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.9654 - accuracy: 0.6697 - val_loss: 1.1277 - val_accuracy: 0.6146
#
# Epoch 00017: val_accuracy improved from 0.51370 to 0.61460, saving model to ./HW_100_ResNet101.hdf5
# Epoch 18/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.8783 - accuracy: 0.7032 - val_loss: 1.0433 - val_accuracy: 0.6394
#
# Epoch 00018: val_accuracy improved from 0.61460 to 0.63940, saving model to ./HW_100_ResNet101.hdf5
# Epoch 19/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.8161 - accuracy: 0.7221 - val_loss: 1.0463 - val_accuracy: 0.6487
#
# Epoch 00019: val_accuracy improved from 0.63940 to 0.64870, saving model to ./HW_100_ResNet101.hdf5
# Epoch 20/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.7481 - accuracy: 0.7470 - val_loss: 0.9414 - val_accuracy: 0.6894
#
# Epoch 00020: val_accuracy improved from 0.64870 to 0.68940, saving model to ./HW_100_ResNet101.hdf5
# Epoch 21/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.6890 - accuracy: 0.7690 - val_loss: 0.9598 - val_accuracy: 0.6877
#
# Epoch 00021: val_accuracy did not improve from 0.68940
# Epoch 22/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.6406 - accuracy: 0.7867 - val_loss: 1.1232 - val_accuracy: 0.6707
#
# Epoch 00022: val_accuracy did not improve from 0.68940
# Epoch 23/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.5729 - accuracy: 0.8087 - val_loss: 1.1471 - val_accuracy: 0.6584
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
#
# Epoch 00023: val_accuracy did not improve from 0.68940
# Epoch 24/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.4298 - accuracy: 0.8575 - val_loss: 1.0328 - val_accuracy: 0.7123
#
# Epoch 00024: val_accuracy improved from 0.68940 to 0.71230, saving model to ./HW_100_ResNet101.hdf5
# Epoch 25/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.3680 - accuracy: 0.8756 - val_loss: 1.1001 - val_accuracy: 0.7030
#
# Epoch 00025: val_accuracy did not improve from 0.71230
# Epoch 26/150
# 50000/50000 [==============================] - 136s 3ms/step - loss: 0.3187 - accuracy: 0.8946 - val_loss: 1.0989 - val_accuracy: 0.7275
#
# Epoch 00026: val_accuracy improved from 0.71230 to 0.72750, saving model to ./HW_100_ResNet101.hdf5
# Epoch 27/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.2750 - accuracy: 0.9084 - val_loss: 1.2466 - val_accuracy: 0.7216
#
# Epoch 00027: val_accuracy did not improve from 0.72750
# Epoch 28/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.2511 - accuracy: 0.9185 - val_loss: 1.2156 - val_accuracy: 0.7286
#
# Epoch 00028: val_accuracy improved from 0.72750 to 0.72860, saving model to ./HW_100_ResNet101.hdf5
# Epoch 29/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.2159 - accuracy: 0.9286 - val_loss: 1.4042 - val_accuracy: 0.7227
#
# Epoch 00029: val_accuracy did not improve from 0.72860
# Epoch 30/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.2024 - accuracy: 0.9337 - val_loss: 1.3618 - val_accuracy: 0.7260
#
# Epoch 00030: val_accuracy did not improve from 0.72860
# Epoch 31/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.1729 - accuracy: 0.9445 - val_loss: 1.3890 - val_accuracy: 0.7296
#
# Epoch 00031: val_accuracy improved from 0.72860 to 0.72960, saving model to ./HW_100_ResNet101.hdf5
# Epoch 32/150
# 50000/50000 [==============================] - 136s 3ms/step - loss: 0.1708 - accuracy: 0.9464 - val_loss: 1.5052 - val_accuracy: 0.7210
#
# Epoch 00032: val_accuracy did not improve from 0.72960
# Epoch 33/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.1454 - accuracy: 0.9545 - val_loss: 1.6069 - val_accuracy: 0.7181
#
# Epoch 00033: val_accuracy did not improve from 0.72960
# Epoch 34/150
# 50000/50000 [==============================] - 136s 3ms/step - loss: 0.1389 - accuracy: 0.9573 - val_loss: 1.5506 - val_accuracy: 0.7260
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
#
# Epoch 00034: val_accuracy did not improve from 0.72960
# Epoch 35/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0831 - accuracy: 0.9749 - val_loss: 1.8363 - val_accuracy: 0.7329
#
# Epoch 00035: val_accuracy improved from 0.72960 to 0.73290, saving model to ./HW_100_ResNet101.hdf5
# Epoch 36/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0599 - accuracy: 0.9817 - val_loss: 1.9372 - val_accuracy: 0.7334
#
# Epoch 00036: val_accuracy improved from 0.73290 to 0.73340, saving model to ./HW_100_ResNet101.hdf5
# Epoch 37/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0550 - accuracy: 0.9830 - val_loss: 1.9952 - val_accuracy: 0.7380
#
# Epoch 00037: val_accuracy improved from 0.73340 to 0.73800, saving model to ./HW_100_ResNet101.hdf5
# Epoch 38/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0521 - accuracy: 0.9844 - val_loss: 2.0717 - val_accuracy: 0.7304
#
# Epoch 00038: val_accuracy did not improve from 0.73800
# Epoch 39/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0472 - accuracy: 0.9863 - val_loss: 2.0969 - val_accuracy: 0.7318
#
# Epoch 00039: val_accuracy did not improve from 0.73800
# Epoch 40/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0427 - accuracy: 0.9870 - val_loss: 2.0740 - val_accuracy: 0.7372
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
#
# Epoch 00040: val_accuracy did not improve from 0.73800
# Epoch 41/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0283 - accuracy: 0.9919 - val_loss: 2.1603 - val_accuracy: 0.7350
#
# Epoch 00041: val_accuracy did not improve from 0.73800
# Epoch 42/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0201 - accuracy: 0.9938 - val_loss: 2.4378 - val_accuracy: 0.7325
#
# Epoch 00042: val_accuracy did not improve from 0.73800
# Epoch 43/150
# 50000/50000 [==============================] - 136s 3ms/step - loss: 0.0191 - accuracy: 0.9944 - val_loss: 2.4234 - val_accuracy: 0.7340
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
#
# Epoch 00043: val_accuracy did not improve from 0.73800
# Epoch 44/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0123 - accuracy: 0.9965 - val_loss: 2.5062 - val_accuracy: 0.7398
#
# Epoch 00044: val_accuracy improved from 0.73800 to 0.73980, saving model to ./HW_100_ResNet101.hdf5
# Epoch 45/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0116 - accuracy: 0.9967 - val_loss: 2.5750 - val_accuracy: 0.7410
#
# Epoch 00045: val_accuracy improved from 0.73980 to 0.74100, saving model to ./HW_100_ResNet101.hdf5
# Epoch 46/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0100 - accuracy: 0.9972 - val_loss: 2.6514 - val_accuracy: 0.7370
#
# Epoch 00046: val_accuracy did not improve from 0.74100
# Epoch 47/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0095 - accuracy: 0.9973 - val_loss: 2.7149 - val_accuracy: 0.7379
#
# Epoch 00047: val_accuracy did not improve from 0.74100
# Epoch 48/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0085 - accuracy: 0.9977 - val_loss: 2.7803 - val_accuracy: 0.7386
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
#
# Epoch 00048: val_accuracy did not improve from 0.74100
# Epoch 49/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0071 - accuracy: 0.9979 - val_loss: 2.8088 - val_accuracy: 0.7385
#
# Epoch 00049: val_accuracy did not improve from 0.74100
# Epoch 50/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0059 - accuracy: 0.9984 - val_loss: 2.8950 - val_accuracy: 0.7380
#
# Epoch 00050: val_accuracy did not improve from 0.74100
# Epoch 51/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0058 - accuracy: 0.9983 - val_loss: 2.9256 - val_accuracy: 0.7386
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
#
# Epoch 00051: val_accuracy did not improve from 0.74100
# Epoch 52/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0055 - accuracy: 0.9984 - val_loss: 2.9192 - val_accuracy: 0.7400
#
# Epoch 00052: val_accuracy did not improve from 0.74100
# Epoch 53/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0058 - accuracy: 0.9985 - val_loss: 2.9136 - val_accuracy: 0.7399
#
# Epoch 00053: val_accuracy did not improve from 0.74100
# Epoch 54/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0045 - accuracy: 0.9988 - val_loss: 2.9206 - val_accuracy: 0.7402
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 3.9062499126885086e-05.
#
# Epoch 00054: val_accuracy did not improve from 0.74100
# Epoch 55/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0043 - accuracy: 0.9989 - val_loss: 2.9337 - val_accuracy: 0.7410
#
# Epoch 00055: val_accuracy did not improve from 0.74100
# Epoch 56/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0052 - accuracy: 0.9988 - val_loss: 2.9355 - val_accuracy: 0.7405
#
# Epoch 00056: val_accuracy did not improve from 0.74100
# Epoch 57/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0044 - accuracy: 0.9989 - val_loss: 2.9230 - val_accuracy: 0.7391
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 1.9531249563442543e-05.
#
# Epoch 00057: val_accuracy did not improve from 0.74100
# Epoch 58/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0038 - accuracy: 0.9990 - val_loss: 2.9417 - val_accuracy: 0.7407
#
# Epoch 00058: val_accuracy did not improve from 0.74100
# Epoch 59/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0041 - accuracy: 0.9990 - val_loss: 2.9541 - val_accuracy: 0.7392
#
# Epoch 00059: val_accuracy did not improve from 0.74100
# Epoch 60/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0041 - accuracy: 0.9987 - val_loss: 2.9520 - val_accuracy: 0.7404
#
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 9.765624781721272e-06.
#
# Epoch 00060: val_accuracy did not improve from 0.74100
# Epoch 61/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0044 - accuracy: 0.9989 - val_loss: 2.9619 - val_accuracy: 0.7411
#
# Epoch 00061: val_accuracy improved from 0.74100 to 0.74110, saving model to ./HW_100_ResNet101.hdf5
# Epoch 62/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0035 - accuracy: 0.9989 - val_loss: 2.9790 - val_accuracy: 0.7404
#
# Epoch 00062: val_accuracy did not improve from 0.74110
# Epoch 63/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0027 - accuracy: 0.9994 - val_loss: 2.9656 - val_accuracy: 0.7409
#
# Epoch 00063: val_accuracy did not improve from 0.74110
# Epoch 64/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 2.9888 - val_accuracy: 0.7406
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 4.882812390860636e-06.
#
# Epoch 00064: val_accuracy did not improve from 0.74110
# Epoch 65/150
# 50000/50000 [==============================] - 136s 3ms/step - loss: 0.0036 - accuracy: 0.9991 - val_loss: 2.9804 - val_accuracy: 0.7419
#
# Epoch 00065: val_accuracy improved from 0.74110 to 0.74190, saving model to ./HW_100_ResNet101.hdf5
# Epoch 66/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0038 - accuracy: 0.9989 - val_loss: 2.9699 - val_accuracy: 0.7411
#
# Epoch 00066: val_accuracy did not improve from 0.74190
# Epoch 67/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0035 - accuracy: 0.9990 - val_loss: 2.9902 - val_accuracy: 0.7422
#
# Epoch 00067: val_accuracy improved from 0.74190 to 0.74220, saving model to ./HW_100_ResNet101.hdf5
# Epoch 68/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0040 - accuracy: 0.9991 - val_loss: 2.9329 - val_accuracy: 0.7412
#
# Epoch 00068: val_accuracy did not improve from 0.74220
# Epoch 69/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0040 - accuracy: 0.9991 - val_loss: 2.9974 - val_accuracy: 0.7411
#
# Epoch 00069: val_accuracy did not improve from 0.74220
# Epoch 70/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 2.9810 - val_accuracy: 0.7409
#
# Epoch 00070: ReduceLROnPlateau reducing learning rate to 2.441406195430318e-06.
#
# Epoch 00070: val_accuracy did not improve from 0.74220
# Epoch 71/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0028 - accuracy: 0.9991 - val_loss: 2.9992 - val_accuracy: 0.7417
#
# Epoch 00071: val_accuracy did not improve from 0.74220
# Epoch 72/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 3.0071 - val_accuracy: 0.7416
#
# Epoch 00072: val_accuracy did not improve from 0.74220
# Epoch 73/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0030 - accuracy: 0.9990 - val_loss: 2.9948 - val_accuracy: 0.7416
#
# Epoch 00073: ReduceLROnPlateau reducing learning rate to 1.220703097715159e-06.
#
# Epoch 00073: val_accuracy did not improve from 0.74220
# Epoch 74/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0029 - accuracy: 0.9993 - val_loss: 3.0111 - val_accuracy: 0.7418
#
# Epoch 00074: val_accuracy did not improve from 0.74220
# Epoch 75/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0042 - accuracy: 0.9989 - val_loss: 2.9835 - val_accuracy: 0.7415
#
# Epoch 00075: val_accuracy did not improve from 0.74220
# Epoch 76/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0038 - accuracy: 0.9991 - val_loss: 3.0003 - val_accuracy: 0.7412
#
# Epoch 00076: ReduceLROnPlateau reducing learning rate to 6.103515488575795e-07.
#
# Epoch 00076: val_accuracy did not improve from 0.74220
# Epoch 77/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 3.0072 - val_accuracy: 0.7420
#
# Epoch 00077: val_accuracy did not improve from 0.74220
# Epoch 78/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 2.9873 - val_accuracy: 0.7415
#
# Epoch 00078: val_accuracy did not improve from 0.74220
# Epoch 79/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0038 - accuracy: 0.9991 - val_loss: 3.0042 - val_accuracy: 0.7407
#
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 3.0517577442878974e-07.
#
# Epoch 00079: val_accuracy did not improve from 0.74220
# Epoch 80/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 2.9947 - val_accuracy: 0.7404
#
# Epoch 00080: val_accuracy did not improve from 0.74220
# Epoch 81/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 3.0040 - val_accuracy: 0.7407
#
# Epoch 00081: val_accuracy did not improve from 0.74220
# Epoch 82/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 3.0077 - val_accuracy: 0.7413
#
# Epoch 00082: ReduceLROnPlateau reducing learning rate to 1.5258788721439487e-07.
#
# Epoch 00082: val_accuracy did not improve from 0.74220
# Epoch 83/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0031 - accuracy: 0.9992 - val_loss: 2.9932 - val_accuracy: 0.7409
#
# Epoch 00083: val_accuracy did not improve from 0.74220
# Epoch 84/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 2.9824 - val_accuracy: 0.7409
#
# Epoch 00084: val_accuracy did not improve from 0.74220
# Epoch 85/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0032 - accuracy: 0.9991 - val_loss: 3.0005 - val_accuracy: 0.7408
#
# Epoch 00085: ReduceLROnPlateau reducing learning rate to 7.629394360719743e-08.
#
# Epoch 00085: val_accuracy did not improve from 0.74220
# Epoch 86/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0036 - accuracy: 0.9990 - val_loss: 3.0020 - val_accuracy: 0.7420
#
# Epoch 00086: val_accuracy did not improve from 0.74220
# Epoch 87/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0032 - accuracy: 0.9991 - val_loss: 3.0039 - val_accuracy: 0.7407
#
# Epoch 00087: val_accuracy did not improve from 0.74220
# Epoch 88/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0034 - accuracy: 0.9992 - val_loss: 2.9702 - val_accuracy: 0.7417
#
# Epoch 00088: ReduceLROnPlateau reducing learning rate to 3.814697180359872e-08.
#
# Epoch 00088: val_accuracy did not improve from 0.74220
# Epoch 89/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0037 - accuracy: 0.9990 - val_loss: 3.0047 - val_accuracy: 0.7414
#
# Epoch 00089: val_accuracy did not improve from 0.74220
# Epoch 90/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0024 - accuracy: 0.9995 - val_loss: 3.0024 - val_accuracy: 0.7407
#
# Epoch 00090: val_accuracy did not improve from 0.74220
# Epoch 91/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 2.9770 - val_accuracy: 0.7404
#
# Epoch 00091: ReduceLROnPlateau reducing learning rate to 1.907348590179936e-08.
#
# Epoch 00091: val_accuracy did not improve from 0.74220
# Epoch 92/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 3.0185 - val_accuracy: 0.7410
#
# Epoch 00092: val_accuracy did not improve from 0.74220
# Epoch 93/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0032 - accuracy: 0.9992 - val_loss: 2.9639 - val_accuracy: 0.7412
#
# Epoch 00093: val_accuracy did not improve from 0.74220
# Epoch 94/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0028 - accuracy: 0.9994 - val_loss: 3.0043 - val_accuracy: 0.7411
#
# Epoch 00094: ReduceLROnPlateau reducing learning rate to 1e-08.
#
# Epoch 00094: val_accuracy did not improve from 0.74220
# Epoch 95/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0033 - accuracy: 0.9992 - val_loss: 3.0033 - val_accuracy: 0.7417
#
# Epoch 00095: val_accuracy did not improve from 0.74220
# Epoch 96/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 2.9853 - val_accuracy: 0.7415
#
# Epoch 00096: val_accuracy did not improve from 0.74220
# Epoch 97/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0037 - accuracy: 0.9992 - val_loss: 2.9961 - val_accuracy: 0.7410
#
# Epoch 00097: val_accuracy did not improve from 0.74220
# Epoch 98/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0044 - accuracy: 0.9990 - val_loss: 2.9846 - val_accuracy: 0.7413
#
# Epoch 00098: val_accuracy did not improve from 0.74220
# Epoch 99/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 2.9890 - val_accuracy: 0.7418
#
# Epoch 00099: val_accuracy did not improve from 0.74220
# Epoch 100/150
# 50000/50000 [==============================] - 138s 3ms/step - loss: 0.0033 - accuracy: 0.9992 - val_loss: 2.9909 - val_accuracy: 0.7422
#
# Epoch 00100: val_accuracy did not improve from 0.74220
# Epoch 101/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 2.9794 - val_accuracy: 0.7406
#
# Epoch 00101: val_accuracy did not improve from 0.74220
# Epoch 102/150
# 50000/50000 [==============================] - 138s 3ms/step - loss: 0.0037 - accuracy: 0.9991 - val_loss: 2.9959 - val_accuracy: 0.7408
#
# Epoch 00102: val_accuracy did not improve from 0.74220
# Epoch 103/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0033 - accuracy: 0.9992 - val_loss: 3.0110 - val_accuracy: 0.7402
#
# Epoch 00103: val_accuracy did not improve from 0.74220
# Epoch 104/150
# 50000/50000 [==============================] - 138s 3ms/step - loss: 0.0034 - accuracy: 0.9992 - val_loss: 2.9966 - val_accuracy: 0.7422
#
# Epoch 00104: val_accuracy did not improve from 0.74220
# Epoch 105/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0038 - accuracy: 0.9991 - val_loss: 2.9854 - val_accuracy: 0.7415
#
# Epoch 00105: val_accuracy did not improve from 0.74220
# Epoch 106/150
# 50000/50000 [==============================] - 138s 3ms/step - loss: 0.0034 - accuracy: 0.9991 - val_loss: 2.9879 - val_accuracy: 0.7409
#
# Epoch 00106: val_accuracy did not improve from 0.74220
# Epoch 107/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0032 - accuracy: 0.9991 - val_loss: 3.0099 - val_accuracy: 0.7411
#
# Epoch 00107: val_accuracy did not improve from 0.74220
# Epoch 108/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 2.9974 - val_accuracy: 0.7410
#
# Epoch 00108: val_accuracy did not improve from 0.74220
# Epoch 109/150
# 50000/50000 [==============================] - 138s 3ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 2.9834 - val_accuracy: 0.7418
#
# Epoch 00109: val_accuracy did not improve from 0.74220
# Epoch 110/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0027 - accuracy: 0.9994 - val_loss: 3.0077 - val_accuracy: 0.7415
#
# Epoch 00110: val_accuracy did not improve from 0.74220
# Epoch 111/150
# 50000/50000 [==============================] - 138s 3ms/step - loss: 0.0030 - accuracy: 0.9989 - val_loss: 2.9932 - val_accuracy: 0.7413
#
# Epoch 00111: val_accuracy did not improve from 0.74220
# Epoch 112/150
# 50000/50000 [==============================] - 138s 3ms/step - loss: 0.0036 - accuracy: 0.9990 - val_loss: 2.9850 - val_accuracy: 0.7412
#
# Epoch 00112: val_accuracy did not improve from 0.74220
# Epoch 113/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0027 - accuracy: 0.9994 - val_loss: 3.0094 - val_accuracy: 0.7408
#
# Epoch 00113: val_accuracy did not improve from 0.74220
# Epoch 114/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 3.0110 - val_accuracy: 0.7407
#
# Epoch 00114: val_accuracy did not improve from 0.74220
# Epoch 115/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0031 - accuracy: 0.9992 - val_loss: 3.0026 - val_accuracy: 0.7406
#
# Epoch 00115: val_accuracy did not improve from 0.74220
# Epoch 116/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 2.9766 - val_accuracy: 0.7412
#
# Epoch 00116: val_accuracy did not improve from 0.74220
# Epoch 117/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 2.9745 - val_accuracy: 0.7404
#
# Epoch 00117: val_accuracy did not improve from 0.74220
# Epoch 118/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0032 - accuracy: 0.9992 - val_loss: 2.9987 - val_accuracy: 0.7416
#
# Epoch 00118: val_accuracy did not improve from 0.74220
# Epoch 119/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0033 - accuracy: 0.9992 - val_loss: 2.9798 - val_accuracy: 0.7417
#
# Epoch 00119: val_accuracy did not improve from 0.74220
# Epoch 120/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0031 - accuracy: 0.9993 - val_loss: 3.0034 - val_accuracy: 0.7414
#
# Epoch 00120: val_accuracy did not improve from 0.74220
# Epoch 121/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 2.9948 - val_accuracy: 0.7407
#
# Epoch 00121: val_accuracy did not improve from 0.74220
# Epoch 122/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0032 - accuracy: 0.9992 - val_loss: 2.9760 - val_accuracy: 0.7415
#
# Epoch 00122: val_accuracy did not improve from 0.74220
# Epoch 123/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 2.9897 - val_accuracy: 0.7404
#
# Epoch 00123: val_accuracy did not improve from 0.74220
# Epoch 124/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 3.0132 - val_accuracy: 0.7405
#
# Epoch 00124: val_accuracy did not improve from 0.74220
# Epoch 125/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 2.9629 - val_accuracy: 0.7417
#
# Epoch 00125: val_accuracy did not improve from 0.74220
# Epoch 126/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0043 - accuracy: 0.9987 - val_loss: 3.0066 - val_accuracy: 0.7414
#
# Epoch 00126: val_accuracy did not improve from 0.74220
# Epoch 127/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 2.9883 - val_accuracy: 0.7410
#
# Epoch 00127: val_accuracy did not improve from 0.74220
# Epoch 128/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 2.9714 - val_accuracy: 0.7412
#
# Epoch 00128: val_accuracy did not improve from 0.74220
# Epoch 129/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 2.9921 - val_accuracy: 0.7411
#
# Epoch 00129: val_accuracy did not improve from 0.74220
# Epoch 130/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0046 - accuracy: 0.9990 - val_loss: 2.9794 - val_accuracy: 0.7417
#
# Epoch 00130: val_accuracy did not improve from 0.74220
# Epoch 131/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0041 - accuracy: 0.9990 - val_loss: 2.9858 - val_accuracy: 0.7416
#
# Epoch 00131: val_accuracy did not improve from 0.74220
# Epoch 132/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 2.9926 - val_accuracy: 0.7410
#
# Epoch 00132: val_accuracy did not improve from 0.74220
# Epoch 133/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0032 - accuracy: 0.9992 - val_loss: 2.9858 - val_accuracy: 0.7412
#
# Epoch 00133: val_accuracy did not improve from 0.74220
# Epoch 134/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0037 - accuracy: 0.9991 - val_loss: 2.9853 - val_accuracy: 0.7413
#
# Epoch 00134: val_accuracy did not improve from 0.74220
# Epoch 135/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 2.9959 - val_accuracy: 0.7409
#
# Epoch 00135: val_accuracy did not improve from 0.74220
# Epoch 136/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0034 - accuracy: 0.9991 - val_loss: 2.9937 - val_accuracy: 0.7418
#
# Epoch 00136: val_accuracy did not improve from 0.74220
# Epoch 137/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0032 - accuracy: 0.9991 - val_loss: 2.9901 - val_accuracy: 0.7413
#
# Epoch 00137: val_accuracy did not improve from 0.74220
# Epoch 138/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0029 - accuracy: 0.9993 - val_loss: 2.9850 - val_accuracy: 0.7413
#
# Epoch 00138: val_accuracy did not improve from 0.74220
# Epoch 139/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0031 - accuracy: 0.9992 - val_loss: 2.9880 - val_accuracy: 0.7412
#
# Epoch 00139: val_accuracy did not improve from 0.74220
# Epoch 140/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 2.9926 - val_accuracy: 0.7414
#
# Epoch 00140: val_accuracy did not improve from 0.74220
# Epoch 141/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0031 - accuracy: 0.9993 - val_loss: 2.9817 - val_accuracy: 0.7417
#
# Epoch 00141: val_accuracy did not improve from 0.74220
# Epoch 142/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 3.0159 - val_accuracy: 0.7414
#
# Epoch 00142: val_accuracy did not improve from 0.74220
# Epoch 143/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 3.0083 - val_accuracy: 0.7411
#
# Epoch 00143: val_accuracy did not improve from 0.74220
# Epoch 144/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 2.9958 - val_accuracy: 0.7409
#
# Epoch 00144: val_accuracy did not improve from 0.74220
# Epoch 145/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0029 - accuracy: 0.9993 - val_loss: 2.9889 - val_accuracy: 0.7408
#
# Epoch 00145: val_accuracy did not improve from 0.74220
# Epoch 146/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0029 - accuracy: 0.9993 - val_loss: 2.9816 - val_accuracy: 0.7413
#
# Epoch 00146: val_accuracy did not improve from 0.74220
# Epoch 147/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0025 - accuracy: 0.9993 - val_loss: 3.0003 - val_accuracy: 0.7408
#
# Epoch 00147: val_accuracy did not improve from 0.74220
# Epoch 148/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0034 - accuracy: 0.9991 - val_loss: 2.9823 - val_accuracy: 0.7415
#
# Epoch 00148: val_accuracy did not improve from 0.74220
# Epoch 149/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0031 - accuracy: 0.9992 - val_loss: 3.0091 - val_accuracy: 0.7409
#
# Epoch 00149: val_accuracy did not improve from 0.74220
# Epoch 150/150
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.0038 - accuracy: 0.9989 - val_loss: 3.0042 - val_accuracy: 0.7407
#
# Epoch 00150: val_accuracy did not improve from 0.74220

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 2.9901716101646425
# Test accuracy: 0.7422000169754028
