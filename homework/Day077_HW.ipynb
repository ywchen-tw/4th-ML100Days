# %% [markdown]
# ## Work
# 1. 請將 Epoch 加到 500 個，並觀察 learning curve 的走勢
# 2. 請將 Optimizer 換成 SGD，並觀察 learning curve 的走勢

# %%
import os
import keras

# 本作業可以不需使用 GPU, 將 GPU 設定為 "無" (若有 GPU 且想開啟，可設為 "0")
os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# Using TensorFlow backend.

# %%
# 從 Keras 的內建功能中，取得 train 與 test 資料集
train, test = keras.datasets.cifar10.load_data()

# %%
# 將 X 與 Y 獨立放進變數
x_train, y_train = train
x_test, y_test = test
# 資料前處理 - 標準化
x_train = x_train / 255.
x_test = x_test / 255.

# 將資料從圖形 (RGB) 轉為向量 (Single Vector)
x_train = x_train.reshape((len(x_train), -1))
x_test = x_test.reshape((len(x_test), -1))

# 將目標轉為 one-hot encoding
y_train = keras.utils.to_categorical(y_train, num_classes=10)
y_test = keras.utils.to_categorical(y_test, num_classes=10)

# %%
def build_mlp():
    """Code Here
    建立你的神經網路
    """
    input_layer = keras.layers.Input([x_train.shape[-1]])
    x = keras.layers.Dense(units=512, activation="relu")(input_layer)
    x = keras.layers.Dense(units=256, activation="relu")(x)
    x = keras.layers.Dense(units=128, activation="relu")(x)
    out = keras.layers.Dense(units=10, activation="softmax")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
model = build_mlp()
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1573376
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________

# %%
"""
Compile 模型
"""

#optimizer = keras.optimizers.Adam(lr=0.001)
optimizer = keras.optimizers.SGD(lr=0.001)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

# %%
"""
設定要訓練的 Epoch 數
"""
model.fit(x_train, y_train, 
          epochs=100, 
          batch_size=256, 
          validation_data=(x_test, y_test), 
          shuffle=True)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 5s 95us/step - loss: 2.2555 - accuracy: 0.1661 - val_loss: 2.2126 - val_accuracy: 0.2044
# Epoch 2/100
# 50000/50000 [==============================] - 5s 94us/step - loss: 2.1801 - accuracy: 0.2241 - val_loss: 2.1539 - val_accuracy: 0.2361
# Epoch 3/100
# 50000/50000 [==============================] - 5s 94us/step - loss: 2.1264 - accuracy: 0.2449 - val_loss: 2.1050 - val_accuracy: 0.2539
# Epoch 4/100
# 50000/50000 [==============================] - 5s 94us/step - loss: 2.0819 - accuracy: 0.2615 - val_loss: 2.0656 - val_accuracy: 0.2666
# Epoch 5/100
# 50000/50000 [==============================] - 5s 94us/step - loss: 2.0456 - accuracy: 0.2745 - val_loss: 2.0329 - val_accuracy: 0.2813
# Epoch 6/100
# 50000/50000 [==============================] - 5s 93us/step - loss: 2.0148 - accuracy: 0.2869 - val_loss: 2.0056 - val_accuracy: 0.2936
# Epoch 7/100
# 50000/50000 [==============================] - 5s 93us/step - loss: 1.9884 - accuracy: 0.2985 - val_loss: 1.9808 - val_accuracy: 0.3055
# Epoch 8/100
# 50000/50000 [==============================] - 5s 94us/step - loss: 1.9657 - accuracy: 0.3101 - val_loss: 1.9600 - val_accuracy: 0.3153
# Epoch 9/100
# 50000/50000 [==============================] - 5s 93us/step - loss: 1.9461 - accuracy: 0.3184 - val_loss: 1.9418 - val_accuracy: 0.3199
# Epoch 10/100
# 50000/50000 [==============================] - 5s 94us/step - loss: 1.9289 - accuracy: 0.3282 - val_loss: 1.9255 - val_accuracy: 0.3298
# Epoch 11/100
# 50000/50000 [==============================] - 5s 94us/step - loss: 1.9138 - accuracy: 0.3339 - val_loss: 1.9112 - val_accuracy: 0.3324
# Epoch 12/100
# 50000/50000 [==============================] - 5s 93us/step - loss: 1.9002 - accuracy: 0.3401 - val_loss: 1.8981 - val_accuracy: 0.3382
# Epoch 13/100
# 50000/50000 [==============================] - 5s 90us/step - loss: 1.8877 - accuracy: 0.3438 - val_loss: 1.8879 - val_accuracy: 0.3410
# Epoch 14/100
# 50000/50000 [==============================] - 5s 92us/step - loss: 1.8765 - accuracy: 0.3477 - val_loss: 1.8759 - val_accuracy: 0.3461
# Epoch 15/100
# 50000/50000 [==============================] - 4s 90us/step - loss: 1.8657 - accuracy: 0.3522 - val_loss: 1.8663 - val_accuracy: 0.3512
# Epoch 16/100
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.8557 - accuracy: 0.3537 - val_loss: 1.8560 - val_accuracy: 0.3538
# Epoch 17/100
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.8465 - accuracy: 0.3567 - val_loss: 1.8505 - val_accuracy: 0.3544
# Epoch 18/100
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.8379 - accuracy: 0.3591 - val_loss: 1.8389 - val_accuracy: 0.3579
# Epoch 19/100
# 50000/50000 [==============================] - 4s 90us/step - loss: 1.8297 - accuracy: 0.3633 - val_loss: 1.8326 - val_accuracy: 0.3599
# Epoch 20/100
# 50000/50000 [==============================] - 4s 89us/step - loss: 1.8220 - accuracy: 0.3657 - val_loss: 1.8240 - val_accuracy: 0.3671
# Epoch 21/100
# 50000/50000 [==============================] - 5s 92us/step - loss: 1.8144 - accuracy: 0.3673 - val_loss: 1.8166 - val_accuracy: 0.3698
# Epoch 22/100
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.8074 - accuracy: 0.3695 - val_loss: 1.8098 - val_accuracy: 0.3726
# Epoch 23/100
# 50000/50000 [==============================] - 5s 90us/step - loss: 1.8008 - accuracy: 0.3726 - val_loss: 1.8025 - val_accuracy: 0.3702
# Epoch 24/100
# 50000/50000 [==============================] - 5s 90us/step - loss: 1.7942 - accuracy: 0.3751 - val_loss: 1.7967 - val_accuracy: 0.3694
# Epoch 25/100
# 50000/50000 [==============================] - 4s 89us/step - loss: 1.7877 - accuracy: 0.3769 - val_loss: 1.7929 - val_accuracy: 0.3749
# Epoch 26/100
# 50000/50000 [==============================] - 5s 90us/step - loss: 1.7817 - accuracy: 0.3781 - val_loss: 1.7856 - val_accuracy: 0.3775
# Epoch 27/100
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.7759 - accuracy: 0.3803 - val_loss: 1.7790 - val_accuracy: 0.3800
# Epoch 28/100
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.7702 - accuracy: 0.3831 - val_loss: 1.7761 - val_accuracy: 0.3794
# Epoch 29/100
# 50000/50000 [==============================] - 5s 92us/step - loss: 1.7642 - accuracy: 0.3838 - val_loss: 1.7670 - val_accuracy: 0.3845
# Epoch 30/100
# 50000/50000 [==============================] - 5s 90us/step - loss: 1.7589 - accuracy: 0.3858 - val_loss: 1.7636 - val_accuracy: 0.3892
# Epoch 31/100
# 50000/50000 [==============================] - 5s 90us/step - loss: 1.7532 - accuracy: 0.3886 - val_loss: 1.7569 - val_accuracy: 0.3872
# Epoch 32/100
# 50000/50000 [==============================] - 4s 89us/step - loss: 1.7483 - accuracy: 0.3904 - val_loss: 1.7522 - val_accuracy: 0.3878
# Epoch 33/100
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.7435 - accuracy: 0.3916 - val_loss: 1.7471 - val_accuracy: 0.3906
# Epoch 34/100
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.7386 - accuracy: 0.3929 - val_loss: 1.7420 - val_accuracy: 0.3917
# Epoch 35/100
# 50000/50000 [==============================] - 5s 92us/step - loss: 1.7337 - accuracy: 0.3951 - val_loss: 1.7385 - val_accuracy: 0.3917
# Epoch 36/100
# 50000/50000 [==============================] - 5s 90us/step - loss: 1.7290 - accuracy: 0.3965 - val_loss: 1.7354 - val_accuracy: 0.3941
# Epoch 37/100
# 50000/50000 [==============================] - 4s 90us/step - loss: 1.7246 - accuracy: 0.3989 - val_loss: 1.7281 - val_accuracy: 0.3968
# Epoch 38/100
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.7199 - accuracy: 0.4010 - val_loss: 1.7244 - val_accuracy: 0.4000
# Epoch 39/100
# 50000/50000 [==============================] - 5s 90us/step - loss: 1.7156 - accuracy: 0.4019 - val_loss: 1.7214 - val_accuracy: 0.3974
# Epoch 40/100
# 50000/50000 [==============================] - 5s 90us/step - loss: 1.7113 - accuracy: 0.4033 - val_loss: 1.7160 - val_accuracy: 0.4033
# Epoch 41/100
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.7071 - accuracy: 0.4032 - val_loss: 1.7117 - val_accuracy: 0.4041
# Epoch 42/100
# 50000/50000 [==============================] - 5s 90us/step - loss: 1.7032 - accuracy: 0.4060 - val_loss: 1.7073 - val_accuracy: 0.4030
# Epoch 43/100
# 50000/50000 [==============================] - 5s 90us/step - loss: 1.6989 - accuracy: 0.4076 - val_loss: 1.7055 - val_accuracy: 0.4056
# Epoch 44/100
# 50000/50000 [==============================] - 5s 90us/step - loss: 1.6949 - accuracy: 0.4090 - val_loss: 1.7013 - val_accuracy: 0.4036
# Epoch 45/100
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.6911 - accuracy: 0.4089 - val_loss: 1.6973 - val_accuracy: 0.4077
# Epoch 46/100
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.6872 - accuracy: 0.4120 - val_loss: 1.6953 - val_accuracy: 0.4095
# Epoch 47/100
# 50000/50000 [==============================] - 4s 89us/step - loss: 1.
100
# 50000/50000 [==============================] - 5s 92us/step - loss: 1.5968 - accuracy: 0.4428 - val_loss: 1.6122 - val_accuracy: 0.4378
# Epoch 76/100
# 50000/50000 [==============================] - 5s 92us/step - loss: 1.5944 - accuracy: 0.4439 - val_loss: 1.6082 - val_accuracy: 0.4337
# Epoch 77/100
# 50000/50000 [==============================] - 4s 90us/step - loss: 1.5914 - accuracy: 0.4457 - val_loss: 1.6097 - val_accuracy: 0.4350
# Epoch 78/100
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.5892 - accuracy: 0.4460 - val_loss: 1.6052 - val_accuracy: 0.4364
# Epoch 79/100
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.5866 - accuracy: 0.4468 - val_loss: 1.6011 - val_accuracy: 0.4364
# Epoch 80/100
# 50000/50000 [==============================] - 4s 89us/step - loss: 1.5840 - accuracy: 0.4472 - val_loss: 1.5995 - val_accuracy: 0.4380
# Epoch 81/100
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.5815 - accuracy: 0.4488 - val_loss: 1.6015 - val_accuracy: 0.4346
# Epoch 82/100
# 50000/50000 [==============================] - 5s 90us/step - loss: 1.5790 - accuracy: 0.4493 - val_loss: 1.5948 - val_accuracy: 0.4374
# Epoch 83/100
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.5767 - accuracy: 0.4505 - val_loss: 1.5921 - val_accuracy: 0.4388
# Epoch 84/100
# 50000/50000 [==============================] - 4s 90us/step - loss: 1.5739 - accuracy: 0.4516 - val_loss: 1.5925 - val_accuracy: 0.4396
# Epoch 85/100
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.5717 - accuracy: 0.4515 - val_loss: 1.5902 - val_accuracy: 0.4402
# Epoch 86/100
# 50000/50000 [==============================] - 4s 89us/step - loss: 1.5691 - accuracy: 0.4526 - val_loss: 1.5879 - val_accuracy: 0.4390
# Epoch 87/100
# 50000/50000 [==============================] - 5s 90us/step - loss: 1.5672 - accuracy: 0.4542 - val_loss: 1.5842 - val_accuracy: 0.4433
# Epoch 88/100
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.5644 - accuracy: 0.4543 - val_loss: 1.5854 - val_accuracy: 0.4399
# Epoch 89/100
# 50000/50000 [==============================] - 4s 90us/step - loss: 1.5625 - accuracy: 0.4558 - val_loss: 1.5817 - val_accuracy: 0.4448
# Epoch 90/100
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.5603 - accuracy: 0.4556 - val_loss: 1.5778 - val_accuracy: 0.4449
# Epoch 91/100
# 50000/50000 [==============================] - 5s 92us/step - loss: 1.5576 - accuracy: 0.4570 - val_loss: 1.5759 - val_accuracy: 0.4441
# Epoch 92/100
# 50000/50000 [==============================] - 5s 90us/step - loss: 1.5554 - accuracy: 0.4566 - val_loss: 1.5738 - val_accuracy: 0.4445
# Epoch 93/100
# 50000/50000 [==============================] - 4s 90us/step - loss: 1.5536 - accuracy: 0.4584 - val_loss: 1.5735 - val_accuracy: 0.4438
# Epoch 94/100
# 50000/50000 [==============================] - 5s 90us/step - loss: 1.5512 - accuracy: 0.4603 - val_loss: 1.5713 - val_accuracy: 0.4478
# Epoch 95/100
# 50000/50000 [==============================] - 4s 90us/step - loss: 1.5490 - accuracy: 0.4604 - val_loss: 1.5705 - val_accuracy: 0.4447
# Epoch 96/100
# 50000/50000 [==============================] - 5s 90us/step - loss: 1.5468 - accuracy: 0.4614 - val_loss: 1.5664 - val_accuracy: 0.4472
# Epoch 97/100
# 50000/50000 [==============================] - 4s 90us/step - loss: 1.5446 - accuracy: 0.4608 - val_loss: 1.5680 - val_accuracy: 0.4445
# Epoch 98/100
# 50000/50000 [==============================] - 5s 91us/step - loss: 1.5428 - accuracy: 0.4605 - val_loss: 1.5666 - val_accuracy: 0.4485
# Epoch 99/100
# 50000/50000 [==============================] - 5s 90us/step - loss: 1.5406 - accuracy: 0.4630 - val_loss: 1.5631 - val_accuracy: 0.4469
# Epoch 100/100
# 50000/50000 [==============================] - 5s 90us/step - loss: 1.5387 - accuracy: 0.4637 - val_loss: 1.5612 - val_accuracy: 0.4469

# %% [markdown]
# ### epochs=500, optimizer=Adam

# %%
import matplotlib.pyplot as plt
# 以視覺畫方式檢視訓練過程

train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]

train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

# %% [markdown]
# ### epochs=100, optimizer=SGD

# %%
import matplotlib.pyplot as plt
# 以視覺畫方式檢視訓練過程

train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]

train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()
